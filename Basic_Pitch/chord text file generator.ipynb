# %%
chrom_notes = ['A', 'Bb', 'B', 'C', 'Db', 'D', 'Eb', 'E', 'F', 'Gb', 'G', 'Ab']
offsets = {
    '1': 0,
    '2': 2,
    '3': 4,
    '4': 5,
    '5': 7,
    '6': 9,
    '7': 11,
    '8': 12,
    '9': 14,
    '10': 16,
    '11': 17,
    '12': 19,
    '13': 21
}
# Returns a note name based on its MIDI note number
def get_note(note_n):
    return chrom_notes[(3 + note_n) % 12]

# Returns the correct note based on a root note of a scale and its degree
def parse_chord(root, number_string):
    note_num = chrom_notes.index(root)
    out = ""
    num = ""
    scale_num = 0
    parentheses = False
    for char in number_string:
        if char == '(':
            parentheses = True
        if char == 'b':
            scale_num -= 1
        if char == '#':
            scale_num += 1
        if char >= '0' and char <= '9':
            num += char
    scale_num += offsets.get(num)
    if (parentheses):
        out = "("
    out += str(get_note(note_num - 3 + scale_num))
    if (parentheses):
        out += ")"
    return out

# %%
# Actually outputs the chord list
for note in chrom_notes:
    f = open("chords without names.txt")
    lines = f.readlines()
    for line in lines:
        parts = line.split()
        string = ""
        for i in range(len(parts)):
            part = parts[i]
            if i == 0:
                string += part.replace('_', note, 1)
                string += " |"
            elif part[0] == 'b' or part[0] == '#' or \
               (part[0] >= '0' and part[0] <= '9') or \
               part[0] == '(':
                string += parse_chord(note, part)
            else: continue
            string += " "
        print(string)
# Out:
# A | A Db E
# AM7 | A Db (E) Ab
# AM9 | A Db (E) Ab (B)
# AM13 | A Db (E) Ab (B) (D) (Gb)
# A6 | A Db (E) Gb
# A69 | A Db (E) Gb B
# AM#4 | A Db (E) (Ab) (B) Eb (Gb)
# AM7b6 | A Db (E) (Ab) (B) (D) F Gb
# A7 | A Db (E) G
# A9 | A Db (E) G B
# A13 | A Db (E) G (B) Gb
# A7#11 | A Db (E) G (B) Eb (Gb)
# A7b9 | A Db (E) G Bb B
# A7#9 | A Db (E) G C B
# Aalt7 | A Db G (Bb)
# Asus4 | A D (E) D
# Asus2 | A B (E) B
# A7sus4 | A D (E) G D
# A11 | A (E) G (B) D
# Ab9sus | A D (E) Bb D B
# Am | A C E
# Am7 | A C (E) G
# Am/M7 | A C (E) Ab (B)
# Am6 | A C (E) Gb
# Am9 | A C (E) G B
# Am11 | A C (E) G (B) D
# Am13 | A C (E) G (B) D (Gb)
# Ao | A C Eb
# Ao7 | A C Eb Gb
# A0 | A C Eb G
# A5 | A E
# Aaug | A Db F
# Aaug7 | A Db F G
# AaugM7 | A Db F Ab
# Bb | Bb D F
# BbM7 | Bb D (F) A
# BbM9 | Bb D (F) A (C)
# BbM13 | Bb D (F) A (C) (Eb) (G)
# Bb6 | Bb D (F) G
# Bb69 | Bb D (F) G C
# BbM#4 | Bb D (F) (A) (C) E (G)
# BbM7b6 | Bb D (F) (A) (C) (Eb) Gb G
# Bb7 | Bb D (F) Ab
# Bb9 | Bb D (F) Ab C
# Bb13 | Bb D (F) Ab (C) G
# Bb7#11 | Bb D (F) Ab (C) E (G)
# Bb7b9 | Bb D (F) Ab B C
# Bb7#9 | Bb D (F) Ab Db C
# Bbalt7 | Bb D Ab (B)
# Bbsus4 | Bb Eb (F) Eb
# Bbsus2 | Bb C (F) C
# Bb7sus4 | Bb Eb (F) Ab Eb
# Bb11 | Bb (F) Ab (C) Eb
# Bbb9sus | Bb Eb (F) B Eb C
# Bbm | Bb Db F
# Bbm7 | Bb Db (F) Ab
# Bbm/M7 | Bb Db (F) A (C)
# Bbm6 | Bb Db (F) G
# Bbm9 | Bb Db (F) Ab C
# Bbm11 | Bb Db (F) Ab (C) Eb
# Bbm13 | Bb Db (F) Ab (C) Eb (G)
# Bbo | Bb Db E
# Bbo7 | Bb Db E G
# Bb0 | Bb Db E Ab
# Bb5 | Bb F
# Bbaug | Bb D Gb
# Bbaug7 | Bb D Gb Ab
# BbaugM7 | Bb D Gb A
# B | B Eb Gb
# BM7 | B Eb (Gb) Bb
# BM9 | B Eb (Gb) Bb (Db)
# BM13 | B Eb (Gb) Bb (Db) (E) (Ab)
# B6 | B Eb (Gb) Ab
# B69 | B Eb (Gb) Ab Db
# BM#4 | B Eb (Gb) (Bb) (Db) F (Ab)
# BM7b6 | B Eb (Gb) (Bb) (Db) (E) G Ab
# B7 | B Eb (Gb) A
# B9 | B Eb (Gb) A Db
# B13 | B Eb (Gb) A (Db) Ab
# B7#11 | B Eb (Gb) A (Db) F (Ab)
# B7b9 | B Eb (Gb) A C Db
# B7#9 | B Eb (Gb) A D Db
# Balt7 | B Eb A (C)
# Bsus4 | B E (Gb) E
# Bsus2 | B Db (Gb) Db
# B7sus4 | B E (Gb) A E
# B11 | B (Gb) A (Db) E
# Bb9sus | B E (Gb) C E Db
# Bm | B D Gb
# Bm7 | B D (Gb) A
# Bm/M7 | B D (Gb) Bb (Db)
# Bm6 | B D (Gb) Ab
# Bm9 | B D (Gb) A Db
# Bm11 | B D (Gb) A (Db) E
# Bm13 | B D (Gb) A (Db) E (Ab)
# Bo | B D F
# Bo7 | B D F Ab
# B0 | B D F A
# B5 | B Gb
# Baug | B Eb G
# Baug7 | B Eb G A
# BaugM7 | B Eb G Bb
# C | C E G
# CM7 | C E (G) B
# CM9 | C E (G) B (D)
# CM13 | C E (G) B (D) (F) (A)
# C6 | C E (G) A
# C69 | C E (G) A D
# CM#4 | C E (G) (B) (D) Gb (A)
# CM7b6 | C E (G) (B) (D) (F) Ab A
# C7 | C E (G) Bb
# C9 | C E (G) Bb D
# C13 | C E (G) Bb (D) A
# C7#11 | C E (G) Bb (D) Gb (A)
# C7b9 | C E (G) Bb Db D
# C7#9 | C E (G) Bb Eb D
# Calt7 | C E Bb (Db)
# Csus4 | C F (G) F
# Csus2 | C D (G) D
# C7sus4 | C F (G) Bb F
# C11 | C (G) Bb (D) F
# Cb9sus | C F (G) Db F D
# Cm | C Eb G
# Cm7 | C Eb (G) Bb
# Cm/M7 | C Eb (G) B (D)
# Cm6 | C Eb (G) A
# Cm9 | C Eb (G) Bb D
# Cm11 | C Eb (G) Bb (D) F
# Cm13 | C Eb (G) Bb (D) F (A)
# Co | C Eb Gb
# Co7 | C Eb Gb A
# C0 | C Eb Gb Bb
# C5 | C G
# Caug | C E Ab
# Caug7 | C E Ab Bb
# CaugM7 | C E Ab B
# Db | Db F Ab
# DbM7 | Db F (Ab) C
# DbM9 | Db F (Ab) C (Eb)
# DbM13 | Db F (Ab) C (Eb) (Gb) (Bb)
# Db6 | Db F (Ab) Bb
# Db69 | Db F (Ab) Bb Eb
# DbM#4 | Db F (Ab) (C) (Eb) G (Bb)
# DbM7b6 | Db F (Ab) (C) (Eb) (Gb) A Bb
# Db7 | Db F (Ab) B
# Db9 | Db F (Ab) B Eb
# Db13 | Db F (Ab) B (Eb) Bb
# Db7#11 | Db F (Ab) B (Eb) G (Bb)
# Db7b9 | Db F (Ab) B D Eb
# Db7#9 | Db F (Ab) B E Eb
# Dbalt7 | Db F B (D)
# Dbsus4 | Db Gb (Ab) Gb
# Dbsus2 | Db Eb (Ab) Eb
# Db7sus4 | Db Gb (Ab) B Gb
# Db11 | Db (Ab) B (Eb) Gb
# Dbb9sus | Db Gb (Ab) D Gb Eb
# Dbm | Db E Ab
# Dbm7 | Db E (Ab) B
# Dbm/M7 | Db E (Ab) C (Eb)
# Dbm6 | Db E (Ab) Bb
# Dbm9 | Db E (Ab) B Eb
# Dbm11 | Db E (Ab) B (Eb) Gb
# Dbm13 | Db E (Ab) B (Eb) Gb (Bb)
# Dbo | Db E G
# Dbo7 | Db E G Bb
# Db0 | Db E G B
# Db5 | Db Ab
# Dbaug | Db F A
# Dbaug7 | Db F A B
# DbaugM7 | Db F A C
# D | D Gb A
# DM7 | D Gb (A) Db
# DM9 | D Gb (A) Db (E)
# DM13 | D Gb (A) Db (E) (G) (B)
# D6 | D Gb (A) B
# D69 | D Gb (A) B E
# DM#4 | D Gb (A) (Db) (E) Ab (B)
# DM7b6 | D Gb (A) (Db) (E) (G) Bb B
# D7 | D Gb (A) C
# D9 | D Gb (A) C E
# D13 | D Gb (A) C (E) B
# D7#11 | D Gb (A) C (E) Ab (B)
# D7b9 | D Gb (A) C Eb E
# D7#9 | D Gb (A) C F E
# Dalt7 | D Gb C (Eb)
# Dsus4 | D G (A) G
# Dsus2 | D E (A) E
# D7sus4 | D G (A) C G
# D11 | D (A) C (E) G
# Db9sus | D G (A) Eb G E
# Dm | D F A
# Dm7 | D F (A) C
# Dm/M7 | D F (A) Db (E)
# Dm6 | D F (A) B
# Dm9 | D F (A) C E
# Dm11 | D F (A) C (E) G
# Dm13 | D F (A) C (E) G (B)
# Do | D F Ab
# Do7 | D F Ab B
# D0 | D F Ab C
# D5 | D A
# Daug | D Gb Bb
# Daug7 | D Gb Bb C
# DaugM7 | D Gb Bb Db
# Eb | Eb G Bb
# EbM7 | Eb G (Bb) D
# EbM9 | Eb G (Bb) D (F)
# EbM13 | Eb G (Bb) D (F) (Ab) (C)
# Eb6 | Eb G (Bb) C
# Eb69 | Eb G (Bb) C F
# EbM#4 | Eb G (Bb) (D) (F) A (C)
# EbM7b6 | Eb G (Bb) (D) (F) (Ab) B C
# Eb7 | Eb G (Bb) Db
# Eb9 | Eb G (Bb) Db F
# Eb13 | Eb G (Bb) Db (F) C
# Eb7#11 | Eb G (Bb) Db (F) A (C)
# Eb7b9 | Eb G (Bb) Db E F
# Eb7#9 | Eb G (Bb) Db Gb F
# Ebalt7 | Eb G Db (E)
# Ebsus4 | Eb Ab (Bb) Ab
# Ebsus2 | Eb F (Bb) F
# Eb7sus4 | Eb Ab (Bb) Db Ab
# Eb11 | Eb (Bb) Db (F) Ab
# Ebb9sus | Eb Ab (Bb) E Ab F
# Ebm | Eb Gb Bb
# Ebm7 | Eb Gb (Bb) Db
# Ebm/M7 | Eb Gb (Bb) D (F)
# Ebm6 | Eb Gb (Bb) C
# Ebm9 | Eb Gb (Bb) Db F
# Ebm11 | Eb Gb (Bb) Db (F) Ab
# Ebm13 | Eb Gb (Bb) Db (F) Ab (C)
# Ebo | Eb Gb A
# Ebo7 | Eb Gb A C
# Eb0 | Eb Gb A Db
# Eb5 | Eb Bb
# Ebaug | Eb G B
# Ebaug7 | Eb G B Db
# EbaugM7 | Eb G B D
# E | E Ab B
# EM7 | E Ab (B) Eb
# EM9 | E Ab (B) Eb (Gb)
# EM13 | E Ab (B) Eb (Gb) (A) (Db)
# E6 | E Ab (B) Db
# E69 | E Ab (B) Db Gb
# EM#4 | E Ab (B) (Eb) (Gb) Bb (Db)
# EM7b6 | E Ab (B) (Eb) (Gb) (A) C Db
# E7 | E Ab (B) D
# E9 | E Ab (B) D Gb
# E13 | E Ab (B) D (Gb) Db
# E7#11 | E Ab (B) D (Gb) Bb (Db)
# E7b9 | E Ab (B) D F Gb
# E7#9 | E Ab (B) D G Gb
# Ealt7 | E Ab D (F)
# Esus4 | E A (B) A
# Esus2 | E Gb (B) Gb
# E7sus4 | E A (B) D A
# E11 | E (B) D (Gb) A
# Eb9sus | E A (B) F A Gb
# Em | E G B
# Em7 | E G (B) D
# Em/M7 | E G (B) Eb (Gb)
# Em6 | E G (B) Db
# Em9 | E G (B) D Gb
# Em11 | E G (B) D (Gb) A
# Em13 | E G (B) D (Gb) A (Db)
# Eo | E G Bb
# Eo7 | E G Bb Db
# E0 | E G Bb D
# E5 | E B
# Eaug | E Ab C
# Eaug7 | E Ab C D
# EaugM7 | E Ab C Eb
# F | F A C
# FM7 | F A (C) E
# FM9 | F A (C) E (G)
# FM13 | F A (C) E (G) (Bb) (D)
# F6 | F A (C) D
# F69 | F A (C) D G
# FM#4 | F A (C) (E) (G) B (D)
# FM7b6 | F A (C) (E) (G) (Bb) Db D
# F7 | F A (C) Eb
# F9 | F A (C) Eb G
# F13 | F A (C) Eb (G) D
# F7#11 | F A (C) Eb (G) B (D)
# F7b9 | F A (C) Eb Gb G
# F7#9 | F A (C) Eb Ab G
# Falt7 | F A Eb (Gb)
# Fsus4 | F Bb (C) Bb
# Fsus2 | F G (C) G
# F7sus4 | F Bb (C) Eb Bb
# F11 | F (C) Eb (G) Bb
# Fb9sus | F Bb (C) Gb Bb G
# Fm | F Ab C
# Fm7 | F Ab (C) Eb
# Fm/M7 | F Ab (C) E (G)
# Fm6 | F Ab (C) D
# Fm9 | F Ab (C) Eb G
# Fm11 | F Ab (C) Eb (G) Bb
# Fm13 | F Ab (C) Eb (G) Bb (D)
# Fo | F Ab B
# Fo7 | F Ab B D
# F0 | F Ab B Eb
# F5 | F C
# Faug | F A Db
# Faug7 | F A Db Eb
# FaugM7 | F A Db E
# Gb | Gb Bb Db
# GbM7 | Gb Bb (Db) F
# GbM9 | Gb Bb (Db) F (Ab)
# GbM13 | Gb Bb (Db) F (Ab) (B) (Eb)
# Gb6 | Gb Bb (Db) Eb
# Gb69 | Gb Bb (Db) Eb Ab
# GbM#4 | Gb Bb (Db) (F) (Ab) C (Eb)
# GbM7b6 | Gb Bb (Db) (F) (Ab) (B) D Eb
# Gb7 | Gb Bb (Db) E
# Gb9 | Gb Bb (Db) E Ab
# Gb13 | Gb Bb (Db) E (Ab) Eb
# Gb7#11 | Gb Bb (Db) E (Ab) C (Eb)
# Gb7b9 | Gb Bb (Db) E G Ab
# Gb7#9 | Gb Bb (Db) E A Ab
# Gbalt7 | Gb Bb E (G)
# Gbsus4 | Gb B (Db) B
# Gbsus2 | Gb Ab (Db) Ab
# Gb7sus4 | Gb B (Db) E B
# Gb11 | Gb (Db) E (Ab) B
# Gbb9sus | Gb B (Db) G B Ab
# Gbm | Gb A Db
# Gbm7 | Gb A (Db) E
# Gbm/M7 | Gb A (Db) F (Ab)
# Gbm6 | Gb A (Db) Eb
# Gbm9 | Gb A (Db) E Ab
# Gbm11 | Gb A (Db) E (Ab) B
# Gbm13 | Gb A (Db) E (Ab) B (Eb)
# Gbo | Gb A C
# Gbo7 | Gb A C Eb
# Gb0 | Gb A C E
# Gb5 | Gb Db
# Gbaug | Gb Bb D
# Gbaug7 | Gb Bb D E
# GbaugM7 | Gb Bb D F
# G | G B D
# GM7 | G B (D) Gb
# GM9 | G B (D) Gb (A)
# GM13 | G B (D) Gb (A) (C) (E)
# G6 | G B (D) E
# G69 | G B (D) E A
# GM#4 | G B (D) (Gb) (A) Db (E)
# GM7b6 | G B (D) (Gb) (A) (C) Eb E
# G7 | G B (D) F
# G9 | G B (D) F A
# G13 | G B (D) F (A) E
# G7#11 | G B (D) F (A) Db (E)
# G7b9 | G B (D) F Ab A
# G7#9 | G B (D) F Bb A
# Galt7 | G B F (Ab)
# Gsus4 | G C (D) C
# Gsus2 | G A (D) A
# G7sus4 | G C (D) F C
# G11 | G (D) F (A) C
# Gb9sus | G C (D) Ab C A
# Gm | G Bb D
# Gm7 | G Bb (D) F
# Gm/M7 | G Bb (D) Gb (A)
# Gm6 | G Bb (D) E
# Gm9 | G Bb (D) F A
# Gm11 | G Bb (D) F (A) C
# Gm13 | G Bb (D) F (A) C (E)
# Go | G Bb Db
# Go7 | G Bb Db E
# G0 | G Bb Db F
# G5 | G D
# Gaug | G B Eb
# Gaug7 | G B Eb F
# GaugM7 | G B Eb Gb
# Ab | Ab C Eb
# AbM7 | Ab C (Eb) G
# AbM9 | Ab C (Eb) G (Bb)
# AbM13 | Ab C (Eb) G (Bb) (Db) (F)
# Ab6 | Ab C (Eb) F
# Ab69 | Ab C (Eb) F Bb
# AbM#4 | Ab C (Eb) (G) (Bb) D (F)
# AbM7b6 | Ab C (Eb) (G) (Bb) (Db) E F
# Ab7 | Ab C (Eb) Gb
# Ab9 | Ab C (Eb) Gb Bb
# Ab13 | Ab C (Eb) Gb (Bb) F
# Ab7#11 | Ab C (Eb) Gb (Bb) D (F)
# Ab7b9 | Ab C (Eb) Gb A Bb
# Ab7#9 | Ab C (Eb) Gb B Bb
# Abalt7 | Ab C Gb (A)
# Absus4 | Ab Db (Eb) Db
# Absus2 | Ab Bb (Eb) Bb
# Ab7sus4 | Ab Db (Eb) Gb Db
# Ab11 | Ab (Eb) Gb (Bb) Db
# Abb9sus | Ab Db (Eb) A Db Bb
# Abm | Ab B Eb
# Abm7 | Ab B (Eb) Gb
# Abm/M7 | Ab B (Eb) G (Bb)
# Abm6 | Ab B (Eb) F
# Abm9 | Ab B (Eb) Gb Bb
# Abm11 | Ab B (Eb) Gb (Bb) Db
# Abm13 | Ab B (Eb) Gb (Bb) Db (F)
# Abo | Ab B D
# Abo7 | Ab B D F
# Ab0 | Ab B D Gb
# Ab5 | Ab Eb
# Abaug | Ab C E
# Abaug7 | Ab C E Gb
# AbaugM7 | Ab C E G

# %%
# Actually outputs the chord list (dict version)
chord_list = []
for note in chrom_notes:
    f = open("chords without names.txt")
    lines = f.readlines()
    for line in lines:
        parts = line.split()
        chord_name = ''
        note_list = []
        for i in range(len(parts)):
            part = parts[i]
            if i == 0:
                chord_name = part.replace('_', note, 1)
            elif part[0] == 'b' or part[0] == '#' or \
               (part[0] >= '0' and part[0] <= '9') or \
               part[0] == '(':
                note_list.append(parse_chord(note, part))
            else: continue
        chord_list.append([chord_name, note_list])
print(chord_list)
# Out:
# [['A', ['A', 'Db', 'E']], ['AM7', ['A', 'Db', '(E)', 'Ab']], ['AM9', ['A', 'Db', '(E)', 'Ab', '(B)']], ['AM13', ['A', 'Db', '(E)', 'Ab', '(B)', '(D)', '(Gb)']], ['A6', ['A', 'Db', '(E)', 'Gb']], ['A69', ['A', 'Db', '(E)', 'Gb', 'B']], ['AM#4', ['A', 'Db', '(E)', '(Ab)', '(B)', 'Eb', '(Gb)']], ['AM7b6', ['A', 'Db', '(E)', '(Ab)', '(B)', '(D)', 'F', 'Gb']], ['A7', ['A', 'Db', '(E)', 'G']], ['A9', ['A', 'Db', '(E)', 'G', 'B']], ['A13', ['A', 'Db', '(E)', 'G', '(B)', 'Gb']], ['A7#11', ['A', 'Db', '(E)', 'G', '(B)', 'Eb', '(Gb)']], ['A7b9', ['A', 'Db', '(E)', 'G', 'Bb', 'B']], ['A7#9', ['A', 'Db', '(E)', 'G', 'C', 'B']], ['Aalt7', ['A', 'Db', 'G', '(Bb)']], ['Asus4', ['A', 'D', '(E)', 'D']], ['Asus2', ['A', 'B', '(E)', 'B']], ['A7sus4', ['A', 'D', '(E)', 'G', 'D']], ['A11', ['A', '(E)', 'G', '(B)', 'D']], ['Ab9sus', ['A', 'D', '(E)', 'Bb', 'D', 'B']], ['Am', ['A', 'C', 'E']], ['Am7', ['A', 'C', '(E)', 'G']], ['Am/M7', ['A', 'C', '(E)', 'Ab', '(B)']], ['Am6', ['A', 'C', '(E)', 'Gb']], ['Am9', ['A', 'C', '(E)', 'G', 'B']], ['Am11', ['A', 'C', '(E)', 'G', '(B)', 'D']], ['Am13', ['A', 'C', '(E)', 'G', '(B)', 'D', '(Gb)']], ['Ao', ['A', 'C', 'Eb']], ['Ao7', ['A', 'C', 'Eb', 'Gb']], ['A0', ['A', 'C', 'Eb', 'G']], ['A5', ['A', 'E']], ['Aaug', ['A', 'Db', 'F']], ['Aaug7', ['A', 'Db', 'F', 'G']], ['AaugM7', ['A', 'Db', 'F', 'Ab']], ['Bb', ['Bb', 'D', 'F']], ['BbM7', ['Bb', 'D', '(F)', 'A']], ['BbM9', ['Bb', 'D', '(F)', 'A', '(C)']], ['BbM13', ['Bb', 'D', '(F)', 'A', '(C)', '(Eb)', '(G)']], ['Bb6', ['Bb', 'D', '(F)', 'G']], ['Bb69', ['Bb', 'D', '(F)', 'G', 'C']], ['BbM#4', ['Bb', 'D', '(F)', '(A)', '(C)', 'E', '(G)']], ['BbM7b6', ['Bb', 'D', '(F)', '(A)', '(C)', '(Eb)', 'Gb', 'G']], ['Bb7', ['Bb', 'D', '(F)', 'Ab']], ['Bb9', ['Bb', 'D', '(F)', 'Ab', 'C']], ['Bb13', ['Bb', 'D', '(F)', 'Ab', '(C)', 'G']], ['Bb7#11', ['Bb', 'D', '(F)', 'Ab', '(C)', 'E', '(G)']], ['Bb7b9', ['Bb', 'D', '(F)', 'Ab', 'B', 'C']], ['Bb7#9', ['Bb', 'D', '(F)', 'Ab', 'Db', 'C']], ['Bbalt7', ['Bb', 'D', 'Ab', '(B)']], ['Bbsus4', ['Bb', 'Eb', '(F)', 'Eb']], ['Bbsus2', ['Bb', 'C', '(F)', 'C']], ['Bb7sus4', ['Bb', 'Eb', '(F)', 'Ab', 'Eb']], ['Bb11', ['Bb', '(F)', 'Ab', '(C)', 'Eb']], ['Bbb9sus', ['Bb', 'Eb', '(F)', 'B', 'Eb', 'C']], ['Bbm', ['Bb', 'Db', 'F']], ['Bbm7', ['Bb', 'Db', '(F)', 'Ab']], ['Bbm/M7', ['Bb', 'Db', '(F)', 'A', '(C)']], ['Bbm6', ['Bb', 'Db', '(F)', 'G']], ['Bbm9', ['Bb', 'Db', '(F)', 'Ab', 'C']], ['Bbm11', ['Bb', 'Db', '(F)', 'Ab', '(C)', 'Eb']], ['Bbm13', ['Bb', 'Db', '(F)', 'Ab', '(C)', 'Eb', '(G)']], ['Bbo', ['Bb', 'Db', 'E']], ['Bbo7', ['Bb', 'Db', 'E', 'G']], ['Bb0', ['Bb', 'Db', 'E', 'Ab']], ['Bb5', ['Bb', 'F']], ['Bbaug', ['Bb', 'D', 'Gb']], ['Bbaug7', ['Bb', 'D', 'Gb', 'Ab']], ['BbaugM7', ['Bb', 'D', 'Gb', 'A']], ['B', ['B', 'Eb', 'Gb']], ['BM7', ['B', 'Eb', '(Gb)', 'Bb']], ['BM9', ['B', 'Eb', '(Gb)', 'Bb', '(Db)']], ['BM13', ['B', 'Eb', '(Gb)', 'Bb', '(Db)', '(E)', '(Ab)']], ['B6', ['B', 'Eb', '(Gb)', 'Ab']], ['B69', ['B', 'Eb', '(Gb)', 'Ab', 'Db']], ['BM#4', ['B', 'Eb', '(Gb)', '(Bb)', '(Db)', 'F', '(Ab)']], ['BM7b6', ['B', 'Eb', '(Gb)', '(Bb)', '(Db)', '(E)', 'G', 'Ab']], ['B7', ['B', 'Eb', '(Gb)', 'A']], ['B9', ['B', 'Eb', '(Gb)', 'A', 'Db']], ['B13', ['B', 'Eb', '(Gb)', 'A', '(Db)', 'Ab']], ['B7#11', ['B', 'Eb', '(Gb)', 'A', '(Db)', 'F', '(Ab)']], ['B7b9', ['B', 'Eb', '(Gb)', 'A', 'C', 'Db']], ['B7#9', ['B', 'Eb', '(Gb)', 'A', 'D', 'Db']], ['Balt7', ['B', 'Eb', 'A', '(C)']], ['Bsus4', ['B', 'E', '(Gb)', 'E']], ['Bsus2', ['B', 'Db', '(Gb)', 'Db']], ['B7sus4', ['B', 'E', '(Gb)', 'A', 'E']], ['B11', ['B', '(Gb)', 'A', '(Db)', 'E']], ['Bb9sus', ['B', 'E', '(Gb)', 'C', 'E', 'Db']], ['Bm', ['B', 'D', 'Gb']], ['Bm7', ['B', 'D', '(Gb)', 'A']], ['Bm/M7', ['B', 'D', '(Gb)', 'Bb', '(Db)']], ['Bm6', ['B', 'D', '(Gb)', 'Ab']], ['Bm9', ['B', 'D', '(Gb)', 'A', 'Db']], ['Bm11', ['B', 'D', '(Gb)', 'A', '(Db)', 'E']], ['Bm13', ['B', 'D', '(Gb)', 'A', '(Db)', 'E', '(Ab)']], ['Bo', ['B', 'D', 'F']], ['Bo7', ['B', 'D', 'F', 'Ab']], ['B0', ['B', 'D', 'F', 'A']] ...
