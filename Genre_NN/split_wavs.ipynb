# %%
import pandas as pd

classical_data = pd.read_csv('classical_dataset.csv')
# print (classical_data)

wavs = list(classical_data['audio_filename'])
for i in range(0, len(wavs)):
    wavs[i] = wavs[i][5:]
    wavs[i] = "wavs/" + wavs[i]

print(wavs)
print(len(wavs))
# Out:
# ['wavs/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--1.wav', 'wavs/MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MID--AUDIO_03_R2_2008_wav--2.wav', 'wavs/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-split_07-07-17_Piano-e_3-02_wav--3.wav', 'wavs/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MID--AUDIO_21_R1_2004_01_Track01_wav.wav', 'wavs/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_04_Track04_wav.wav', 'wavs/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_04_WAV.wav', 'wavs/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_07_WAV.wav', 'wavs/ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_19_R2_2013_wav--3.wav', 'wavs/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_04_WAV.wav', 'wavs/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_05_WAV.wav', 'wavs/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_09_Track09_wav.wav', 'wavs/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_04_Track04_wav.wav', 'wavs/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_11_R3_2013_wav--3.wav', 'wavs/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_15_Track15_wav.wav', 'wavs/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5.wav', 'wavs/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_06_WAV.wav', 'wavs/MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--3.wav', 'wavs/MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_02_Track02_wav.wav', 'wavs/MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--4.wav', 'wavs/MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--2.wav', 'wavs/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--4.wav', 'wavs/MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--2.wav', 'wavs/MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--2.wav', 'wavs/MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--2.wav', 'wavs/ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_03_R1_2013_wav--4.wav', 'wavs/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_12_Track12_wav.wav', 'wavs/MIDI-Unprocessed_Recital12_MID--AUDIO_12_R1_2018_wav--2.wav', 'wavs/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_04_WAV.wav', 'wavs/MIDI-Unprocessed_19_R1_2009_03-04_ORIG_MID--AUDIO_19_R1_2009_19_R1_2009_04_WAV.wav', 'wavs/MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--4.wav', 'wavs/MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_21_R1_2014_wav--6.wav', 'wavs/MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_22_R1_2014_wav--4.wav', 'wavs/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav.wav', 'wavs/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_03_Track03_wav.wav', 'wavs/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_08_WAV.wav', 'wavs/MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1.wav', 'wavs/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--3.wav', 'wavs/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--4.wav', 'wavs/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_01_WAV.wav', 'wavs/MIDI-Unprocessed_02_R3_2008_01-03_ORIG_MID--AUDIO_02_R3_2008_wav--3.wav', 'wavs/MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_01_Track01_wav.wav', 'wavs/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--4.wav', 'wavs/ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_18_R3_2013_wav--2.wav', 'wavs/MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--3.wav', 'wavs/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--3.wav', 'wavs/MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--4.wav', 'wavs/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--3.wav', 'wavs/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_03_Track03_wav.wav', 'wavs/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--4.wav', 'wavs/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_02_WAV.wav ...
# 1276

# %% [markdown]
# Get mp3 names

# %%
mp3s = []
for i in range(len(wavs)):
    mp3_name = str.rstrip(wavs[i], "wav")
    mp3_name = str.lstrip(mp3_name, "wavs")
    mp3_name = "mp3" + mp3_name + "mp3"
    mp3s.append(mp3_name)
print(mp3s)
# Out:
# ['mp3/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--1.mp3', 'mp3/MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MID--AUDIO_03_R2_2008_wav--2.mp3', 'mp3/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-split_07-07-17_Piano-e_3-02_wav--3.mp3', 'mp3/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MID--AUDIO_21_R1_2004_01_Track01_wav.mp3', 'mp3/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_04_Track04_wav.mp3', 'mp3/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_04_WAV.mp3', 'mp3/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_07_WAV.mp3', 'mp3/ORIG-MIDI_03_7_8_13_Group__MID--AUDIO_19_R2_2013_wav--3.mp3', 'mp3/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_04_WAV.mp3', 'mp3/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_05_WAV.mp3', 'mp3/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_09_Track09_wav.mp3', 'mp3/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_04_Track04_wav.mp3', 'mp3/ORIG-MIDI_02_7_10_13_Group_MID--AUDIO_11_R3_2013_wav--3.mp3', 'mp3/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_15_Track15_wav.mp3', 'mp3/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--5.mp3', 'mp3/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_06_WAV.mp3', 'mp3/MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--3.mp3', 'mp3/MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_02_Track02_wav.mp3', 'mp3/MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--4.mp3', 'mp3/MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--2.mp3', 'mp3/MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--4.mp3', 'mp3/MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--2.mp3', 'mp3/MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--2.mp3', 'mp3/MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--2.mp3', 'mp3/ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_03_R1_2013_wav--4.mp3', 'mp3/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_12_Track12_wav.mp3', 'mp3/MIDI-Unprocessed_Recital12_MID--AUDIO_12_R1_2018_wav--2.mp3', 'mp3/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_04_WAV.mp3', 'mp3/MIDI-Unprocessed_19_R1_2009_03-04_ORIG_MID--AUDIO_19_R1_2009_19_R1_2009_04_WAV.mp3', 'mp3/MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--4.mp3', 'mp3/MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_21_R1_2014_wav--6.mp3', 'mp3/MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_22_R1_2014_wav--4.mp3', 'mp3/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav.mp3', 'mp3/MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_03_Track03_wav.mp3', 'mp3/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_08_WAV.mp3', 'mp3/MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1.mp3', 'mp3/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--3.mp3', 'mp3/MIDI-UNPROCESSED_14-15_R1_2014_MID--AUDIO_15_R1_2014_wav--4.mp3', 'mp3/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_01_WAV.mp3', 'mp3/MIDI-Unprocessed_02_R3_2008_01-03_ORIG_MID--AUDIO_02_R3_2008_wav--3.mp3', 'mp3/MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_01_Track01_wav.mp3', 'mp3/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--4.mp3', 'mp3/ORIG-MIDI_03_7_10_13_Group_MID--AUDIO_18_R3_2013_wav--2.mp3', 'mp3/MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--3.mp3', 'mp3/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--3.mp3', 'mp3/MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--4.mp3', 'mp3/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--3.mp3', 'mp3/MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_03_Track03_wav.mp3', 'mp3/MIDI-UNPROCESSED_09-10_R1_2014_MID--AUDIO_09_R1_2014_wav--4.mp3', 'mp3/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_02_WAV.mp3', 'mp3/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID ...

# %%
from pydub import AudioSegment
import math
import re

class SplitWavAudioMubin():
    def __init__(self, folder, filename, path):
        self.folder = folder
        self.filename = filename
        self.filepath = path
        
        self.audio = AudioSegment.from_file(self.filepath, format="mp3")
    
    def get_duration(self):
        return self.audio.duration_seconds
    
    def single_split(self, from_min, to_min, split_filename):
        t1 = from_min * 15 * 1000
        t2 = to_min * 15 * 1000
        split_audio = self.audio[t1:t2]
        split_audio.export(self.folder + '\\' + split_filename, format="mp3")
        
    def multiple_split(self, min_per_split):
        total_mins = math.ceil(self.get_duration() / 15)
        for i in range(0, total_mins, min_per_split):
            split_fn = str(i) + '_' + self.filename
            self.single_split(i, i+min_per_split, split_fn)
            print(str(split_fn) + ' Done')
            if i == total_mins - min_per_split:
                print('All splited successfully')

new_folder = "audio"
for fp in mp3s:
    new_name = fp
    new_name = re.sub("_wav", "", new_name)
    new_name = re.sub("mp3/", "", new_name)
    split_wav = SplitWavAudioMubin(new_folder, new_name, fp)
    split_wav.multiple_split(min_per_split=1)
# Out:
# mp3/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--1.mp3 audio MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3
# 0_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 1_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 2_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 3_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 4_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 5_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 6_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 7_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 8_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 9_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 10_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 11_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 12_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 13_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 14_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 15_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 16_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 17_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 18_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 19_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 20_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 21_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 22_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# 23_MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018--1.mp3 Done
# All splited successfully
