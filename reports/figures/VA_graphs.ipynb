# %% [markdown]
# Generating graphs of emotion points on VA axes with examples of predictions

# %%
import matplotlib.pyplot as plt   
import pandas as pd

VAs = pd.read_csv("VAdata.csv")
print(VAs)
emotions = VAs["Emotion"]
valences = VAs["Valence"]
arousals = VAs["      Arousal"]
annotate = VAs["Annotate"]

fig, ax = plt.subplots()
plt.xlim([1,9])
plt.ylim([1,9])
plt.xlabel("Valence")
plt.ylabel("Arousal")
ax.scatter(valences, arousals)

for i, txt in enumerate(emotions):
    if(annotate[i]):
        ax.annotate(txt, (valences[i], arousals[i]))
# Out:
#          Emotion        Arousal  Valence  Annotate
# 0   Affectionate           2.90     2.57         0
# 1     Aggressive           8.12     7.67         0
# 2      Aggrieved           5.91     5.65         0
# 3        Aghast            7.20     6.47         0
# 4       Agonized           6.99     7.52         0
# ..           ...            ...      ...       ...
# 57          Sick           6.71     7.60         0
# 58     Surprised           5.74     4.09         1
# 59    Triumphant           5.50     3.48         0
# 60      Troubled           6.43     5.77         1
# 61       Wistful           5.47     6.03         1
#
# [62 rows x 4 columns]
